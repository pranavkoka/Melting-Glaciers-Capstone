# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv(r"data\model_input.csv")
dataset = df.drop(columns=["Unnamed: 0", "Min Temp", "Max Temp", "percentile_25", "percentile_75"])
dataset
# Out:
#      Mean Temp   RAINFALL month_year    median
# 0    22.178833   0.085958    2013-04  0.455720
# 1    26.819516   0.413366    2013-05  0.665620
# 2    25.359833  31.586529    2013-06  0.226039
# 3    25.052258  20.653476    2013-07  0.249820
# 4    24.369032  24.446940    2013-08  0.267682
# ..         ...        ...        ...       ...
# 112  25.292838  13.266669    2022-08  0.238900
# 113  23.823002  11.473897    2022-09  0.244405
# 114  20.420344   3.875470    2022-10  0.419238
# 115  16.548313   0.000000    2022-11  0.518314
# 116  12.674815   0.000000    2022-12  0.400156
#
# [117 rows x 4 columns]

# %%
dataset['month_year'] = pd.to_datetime(dataset['month_year'])
dataset['year'] = dataset['month_year'].dt.year
dataset['month'] = dataset['month_year'].dt.month
reg_dataset = dataset.drop(columns=["month_year"])
reg_dataset
# Out:
#      Mean Temp   RAINFALL    median  year  month
# 0    22.178833   0.085958  0.455720  2013      4
# 1    26.819516   0.413366  0.665620  2013      5
# 2    25.359833  31.586529  0.226039  2013      6
# 3    25.052258  20.653476  0.249820  2013      7
# 4    24.369032  24.446940  0.267682  2013      8
# ..         ...        ...       ...   ...    ...
# 112  25.292838  13.266669  0.238900  2022      8
# 113  23.823002  11.473897  0.244405  2022      9
# 114  20.420344   3.875470  0.419238  2022     10
# 115  16.548313   0.000000  0.518314  2022     11
# 116  12.674815   0.000000  0.400156  2022     12
#
# [117 rows x 5 columns]

# %%
reg_dataset['timeindex'] = (reg_dataset['year'] - 2013)*12 + reg_dataset['month'] - 3
reg_dataset.drop(columns = ['year', 'month'], inplace=True)

# %%
median = reg_dataset['median']
reg_dataset.drop(columns='median', inplace=True)
reg_dataset['Median NDSI'] = median
reg_dataset
# Out:
#      Mean Temp   RAINFALL  timeindex  Median NDSI
# 0    22.178833   0.085958          1     0.455720
# 1    26.819516   0.413366          2     0.665620
# 2    25.359833  31.586529          3     0.226039
# 3    25.052258  20.653476          4     0.249820
# 4    24.369032  24.446940          5     0.267682
# ..         ...        ...        ...          ...
# 112  25.292838  13.266669        113     0.238900
# 113  23.823002  11.473897        114     0.244405
# 114  20.420344   3.875470        115     0.419238
# 115  16.548313   0.000000        116     0.518314
# 116  12.674815   0.000000        117     0.400156
#
# [117 rows x 4 columns]

# %%
def multipleLR(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
    regressor = LinearRegression()
    regressor.fit(X_train, y_train)
    y_pred = regressor.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    print("RMSE: ", rmse)
    print("R2: ", r2)

# %%
def polynomialRegression(X, y, degree):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    poly = PolynomialFeatures(degree=degree)
    X_poly_train = poly.fit_transform(X_train)
    X_poly_test = poly.transform(X_test)
    poly_regressor = LinearRegression()
    poly_regressor.fit(X_poly_train, y_train)
    y_pred = poly_regressor.predict(X_poly_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    
    print(f"Polynomial Degree: {degree}")
    print("RMSE: ", rmse)
    print("R2: ", r2)

# %%
def DTRegression(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
    regressor = DecisionTreeRegressor(random_state = 0)
    regressor.fit(X_train,y_train)
    y_pred = regressor.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    print("RMSE: ", rmse)
    print("R2: ", r2)

# %%
def RFRegression(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
    regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
    regressor.fit(X_train,y_train)
    y_pred = regressor.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    print("RMSE: ", rmse)
    print("R2: ", r2)

# %%
X = reg_dataset.iloc[:, :-1].values
y = reg_dataset.iloc[:, -1].values
print(X)
print(y)
# Out:
# [[2.21788334e+01 8.59575709e-02 1.00000000e+00]
#  [2.68195160e+01 4.13366435e-01 2.00000000e+00]
#  [2.53598333e+01 3.15865286e+01 3.00000000e+00]
#  [2.50522580e+01 2.06534755e+01 4.00000000e+00]
#  [2.43690322e+01 2.44469404e+01 5.00000000e+00]
#  [2.39613334e+01 7.31920172e+00 6.00000000e+00]
#  [2.10993548e+01 1.03277233e+00 7.00000000e+00]
#  [1.57763332e+01 4.08671377e-01 8.00000000e+00]
#  [1.22835484e+01 2.27593876e-01 9.00000000e+00]
#  [1.01951563e+01 3.34616596e+00 1.00000000e+01]
#  [1.14715847e+01 3.92721932e+00 1.10000000e+01]
#  [1.62364870e+01 2.17313609e+00 1.20000000e+01]
#  [2.12365510e+01 8.25622966e-01 1.30000000e+01]
#  [2.47275136e+01 1.08771570e+00 1.40000000e+01]
#  [2.78287476e+01 2.76074192e+00 1.50000000e+01]
#  [2.54392737e+01 1.50794725e+01 1.60000000e+01]
#  [2.54883951e+01 1.95885474e+01 1.70000000e+01]
#  [2.37061987e+01 4.22894520e+00 1.80000000e+01]
#  [2.06250943e+01 2.80761354e+00 1.90000000e+01]
#  [1.66046698e+01 0.00000000e+00 2.00000000e+01]
#  [1.14790482e+01 9.41396663e-01 2.10000000e+01]
#  [9.74349455e+00 9.81567876e-01 2.20000000e+01]
#  [1.39265681e+01 7.27307899e-01 2.30000000e+01]
#  [1.65485788e+01 5.36248949e+00 2.40000000e+01]
#  [2.12080986e+01 1.86491981e+00 2.50000000e+01]
#  [2.63157168e+01 3.84364219e-01 2.60000000e+01]
#  [2.59980942e+01 4.94240728e+00 2.70000000e+01]
#  [2.46421041e+01 1.59032645e+01 2.80000000e+01]
#  [2.46502470e+01 1.85026867e+01 2.90000000e+01]
#  [2.43014865e+01 2.55532201e+00 3.00000000e+01]
#  [2.15420005e+01 7.20505349e-01 3.10000000e+01]
#  [1.72551353e+01 1.15330487e-01 3.20000000e+01]
#  [1.25941061e+01 2.27351560e-01 3.30000000e+01]
#  [1.12979532e+01 0.00000000e+00 3.40000000e+01]
#  [1.43314783e+01 6.78103698e-01 3.50000000e+01]
#  [1.86875549e+01 9.58301767e-01 3.60000000e+01]
#  [2.43563421e+01 2.08233349e-01 3.70000000e+01]
#  [2.58393118e+01 1.51003014e+00 3.80000000e+01]
#  [2.65702311e+01 5.95228323e+00 3.90000000e+01]
#  [2.47062316e+01 1.80935673e+01 4.00000000e+01]
#  [2.48462889e+01 1.19522079e+01 4.10000000e+01]
#  [1.90722936e+01 2.66104679e-01 9.60000000e+01]
#  [2.18502786e+01 8.19894216e-01 9.70000000e+01]
#  [2.35461181e+01 5.07020638e+00 9.80000000e+01]
#  [2.53374631e+01 5.20293610e+00 9.90000000e+01]
#  [2.55252953e+01 2.25388876e+01 1.00000000e+02]
#  [2.51500004e+01 1.34639585e+01 1.01000000e+02]
#  [2.41660504e+01 1.15326394e+01 1.02000000e+02]
#  [2.13906686e+01 2.11130727e+00 1.03000000e+02]
#  [1.59166892e+01 0.00000000e+00 1.04000000e+02]
#  [1.16045001e+01 6.45885093e-02 1.05000000e+02]
#  [9.79453512e+00 4.58395633e+00 1.06000000e+02]
#  [1.17681037e+01 1.77351299e+00 1.07000000e+02]
#  [2.04292373e+01 0.00000000e+00 1.08000000e+02]
#  [2.54927687e+01 1.60179506e-02 1.09000000e+02]
#  [2.59411603e+01 1.86153011e+00 1.10000000e+02]
#  [2.72524418e+01 3.76720582e+00 1.11000000e+02]
#  [2.52421746e+01 1.59358514e+01 1.12000000e+02]
#  [2.52928382e+01 1.32666691e+01 1.13000000e+02]
#  [2.38230022e+01 1.14738974e+01 1.14000000e+02]
#  [2.04203445e+01 3.87546962e+00 1.15000000e+02]
#  [1.65483128e+01 0.00000000e+00 1.16000000e+02]
#  [1.26748146e+01 0.00000000e+00 1.17000000e+02]]
# [ 0.45572034  0.66562017  0.22603931  0.24981961  0.26768151  0.1393399
#   0.22464314  0.65540954  0.12883048  0.71885561  0.82668278  0.82715231
#   0.63502003  0.40792971  0.67481297  0.50674207  0.06456708 -0.1141739
#   0.84057182  0.33269369  0.13610657  0.74439472  0.84714024  0.5841942
#   0.92162507  0.26356515  0.24498655  0.4531307   0.18783691 -0.12025199
#   0.09119889  0.16794678 -0.02382688  0.65552881  0.82750181  0.59899907
#   0.82417772  0.31742987  0.23367545  0.26216867  0.24311796 -0.09716922
#   0.18675722 -0.14717413 -0.24734463  0.78766469  0.77609579  0.80564364
#   0.89003685  0.79201717  0.39797259  0.22421052  0.63989213  0.17809593
#  -0.06303366  0.28221342  0.54856903  0.38150754  0.66594503  0.72187905
#   0.7999359   0.78412805  0.28042909 -0.18722283  0.30120048  0.09007902
#   0.63456375  0.26681629  0.78739506  0.81609869  0.74361559  0.84710248
#   0.92026421  0.88999999  0.58225154  0.1847573   0.25259522  0.0344044
#   0.42795268  0.62716065  0.85883337  0.67176265  0.84054243  0.71744125
#   0.62514651  0.90010224  0.78603819  0.2369441   0.52744479  0.46411569
#  -0.3134476  -0.03075729  0.86733188  0.44495938  0.75207095  0.87103445
#   0.81767297  0.3228648   0.37331122  0.20453985  0.11312809  0.47475647
#  -0.01578026  0.78703443  0.45072876  0.85919188  0.82435364  0.93345952
#   0.36034923  0.19921199  0.28175125  0.23201991  0.23889967  0.24440501
#   0.41923768  0.51831405  0.40015633]

# %%
multipleLR(X,y)
# Out:
# RMSE:  0.2924386847297578
# R2:  0.12283038574886185

# %%
polynomialRegression(X,y,2)
# Out:
# Polynomial Degree: 2
# RMSE:  0.2895762963690349
# R2:  0.13991781210790655

# %%
DTRegression(X,y)
# Out:
# RMSE:  0.4336580046190202
# R2:  -0.928895364647701

# %%
RFRegression(X,y)
# Out:
# RMSE:  0.30354800144396643
# R2:  0.05491974292827162
